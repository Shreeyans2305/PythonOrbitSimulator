# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def acceleration(pos_i, pos_j, m_j, G=1.0):
    r = pos_j - pos_i
    dist = np.linalg.norm(r)
    return G * m_j * r / dist**3

# %%
dt = 0.001
steps = 20000

positions = []

for _ in range(steps):
    r = r_planet - r_star
    dist = np.linalg.norm(r)
    a = -G * M * r / dist**3

    r_planet += v_planet * dt + 0.5 * a * dt**2
    a_new = -G * M * r_planet / np.linalg.norm(r_planet)**3
    v_planet += 0.5 * (a + a_new) * dt

    positions.append(r_planet.copy())

# %%
positions = np.array(positions)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(positions[:,0], positions[:,1], positions[:,2])
ax.scatter(0, 0, 0, color='yellow', s=100)

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
plt.show()
